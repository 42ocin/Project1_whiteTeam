# %%
#imports
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
# %matplotlib inLine
from scipy.stats import linregress

# %%
#Reading in our CSV File
heartdiseaseCSVPath = "Resources/heart_2020_cleaned.csv"
heartdiseaseDF = pd.read_csv(heartdiseaseCSVPath)

# %%
#Viewing Variables
heartdiseaseDF.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# 1              Yes  Very good        7.0     No            No         No
# 2              Yes       Fair        8.0    Yes            No         No
# 3               No       Good        6.0     No            No        Yes
# 4              Yes  Very good        8.0     No            No         No

# %%
#Creating a DataFrame for individuals that have heart disease
yesheartDisease = heartdiseaseDF[(heartdiseaseDF["HeartDisease"] == "Yes")]
yesheartDisease

yesheartdiseaseMeanBMI = yesheartDisease.groupby("HeartDisease")["BMI"].mean()
yesheartdiseaseMeanPhysicalHealth = yesheartDisease.groupby("HeartDisease")["PhysicalHealth"].mean()
yesheartdiseaseMeanMentalHealth = yesheartDisease.groupby("HeartDisease")["MentalHealth"].mean()
yesheartdiseaseMeanSleepTime = yesheartDisease.groupby("HeartDisease")["SleepTime"].mean()

yesheartdiseaseAvg = {
    "Mean BMI": yesheartdiseaseMeanBMI,
    "Mean Physical Health": yesheartdiseaseMeanPhysicalHealth,
    "Mean Mental Health": yesheartdiseaseMeanMentalHealth,
    "Mean Sleep Time": yesheartdiseaseMeanSleepTime
}

yesheartdiseaseAvgDF = pd.DataFrame(yesheartdiseaseAvg)
yesheartdiseaseAvgDF
# Out:
#                Mean BMI  Mean Physical Health  Mean Mental Health  \
# HeartDisease
# Yes           29.401592              7.808242            4.641764
#
#               Mean Sleep Time
# HeartDisease
# Yes                  7.136156

# %%
noheartDisease = heartdiseaseDF[(heartdiseaseDF["HeartDisease"] == "No")]
noheartDisease

noheartdiseaseMeanBMI = noheartDisease.groupby("HeartDisease")["BMI"].mean()
noheartdiseaseMeanPhysicalHealth = noheartDisease.groupby("HeartDisease")["PhysicalHealth"].mean()
noheartdiseaseMeanMentalHealth = noheartDisease.groupby("HeartDisease")["MentalHealth"].mean()
noheartdiseaseMeanSleepTime = noheartDisease.groupby("HeartDisease")["SleepTime"].mean()

noheartdiseaseAvg = {
    "Mean BMI": noheartdiseaseMeanBMI,
    "Mean Physical Health": noheartdiseaseMeanPhysicalHealth,
    "Mean Mental Health": noheartdiseaseMeanMentalHealth,
    "Mean Sleep Time": noheartdiseaseMeanSleepTime
}

noheartdiseaseAvgDF = pd.DataFrame(noheartdiseaseAvg)
noheartdiseaseAvgDF
# Out:
#                Mean BMI  Mean Physical Health  Mean Mental Health  \
# HeartDisease
# No            28.224658              2.956416            3.828778
#
#               Mean Sleep Time
# HeartDisease
# No                   7.093416

# %%
#Mean values of our numerical variables
combinedAvg = pd.concat([yesheartdiseaseAvgDF, noheartdiseaseAvgDF])
combinedAvgDF = pd.DataFrame(combinedAvg)
combinedAvgDF
# Out:
#                Mean BMI  Mean Physical Health  Mean Mental Health  \
# HeartDisease
# Yes           29.401592              7.808242            4.641764
# No            28.224658              2.956416            3.828778
#
#               Mean Sleep Time
# HeartDisease
# Yes                  7.136156
# No                   7.093416

# %%
#creating a chart plotting mean values of our numerical variables
import matplotlib.pyplot as plt

# Define the categories and mean values for heart disease 'yes' and 'no'
categories = ['BMI', 'Physical Health', 'Mental Health', 'Sleep Time']
mean_values_yes = [29.401592, 7.808242, 4.641764, 7.136156]
mean_values_no = [28.224658, 2.956416, 3.828778, 7.093416]

# Set the width of the bars
bar_width = 0.35

# Set the x locations for the groups
index = range(len(categories))

# Create the bar chart
plt.bar(index, mean_values_yes, bar_width, label='Heart Disease: Yes')
plt.bar([i + bar_width for i in index], mean_values_no, bar_width, label='Heart Disease: No')

# Add labels, title, and legend
plt.xlabel('Categories')
plt.ylabel('Mean Values')
plt.title('Comparison of Mean Values for Heart Disease: Yes vs No')
plt.xticks([i + bar_width / 2 for i in index], categories)
plt.legend()
plt.savefig("./Resources/HeartDiseaseCompMeanVals.png")


# Show the plot
plt.show()

# %%
#age group comparison
heartdiseaseAgeCategory = yesheartDisease.groupby("HeartDisease")["AgeCategory"].value_counts()
noheartdiseaseAgeCategory = noheartDisease.groupby("HeartDisease")["AgeCategory"].value_counts()

print(heartdiseaseAgeCategory)
print(noheartdiseaseAgeCategory)

heartdiseaseAges = heartdiseaseAgeCategory.groupby("AgeCategory").value_counts()
numberperCategory = heartdiseaseAgeCategory.sort_values(ascending=True)
numberperCategory.plot(kind="bar", color = 'blue', figsize=(8,4))
plt.xlabel("Age Categories")
plt.ylabel("Number with Heart Disease")
plt.show()
# Out:
# HeartDisease  AgeCategory
# Yes           80 or older    5449
#               70-74          4847
#               65-69          4101
#               75-79          4049
#               60-64          3327
#               55-59          2202
#               50-54          1383
#               45-49           744
#               40-44           486
#               35-39           296
#               30-34           226
#               25-29           133
#               18-24           130
# Name: count, dtype: int64
# HeartDisease  AgeCategory
# No            60-64          30359
#               65-69          30050
#               55-59          27555
#               70-74          26218
#               50-54          23999
#               45-49          21047
#               18-24          20934
#               40-44          20520
#               35-39          20254
#               80 or older    18704
#               30-34          18527
#               75-79          17433
#               25-29          16822
# Name: count, dtype: int64

# %%
#population by age category chart (demographic info)
agecategoryCount = heartdiseaseDF.groupby('AgeCategory').size().reset_index(name='Count')

plt.figure(figsize=(12, 4))
plt.bar(agecategoryCount.index, agecategoryCount['Count'], color='red')
plt.xlabel("Age Categories")
plt.ylabel("Number of Respondents")
plt.xticks(range(len(agecategoryCount)), agecategoryCount['AgeCategory'])
plt.show()

# %%
# pull age categories and the amount of people in each category
heartdiseaseAgeCategory = yesheartDisease.groupby("HeartDisease")["AgeCategory"].value_counts().reset_index(name='Count')

# set plot colors
colorPick4 = ['papayawhip','powderblue','peachpuff','mediumspringgreen','palevioletred',
             'steelblue', 'mistyrose','wheat','palegreen','lightsteelblue','springgreen',
             'coral', 'antiquewhite']

#Scatter plot of Ages with Heart Disease
plt.figure(figsize=(10, 4))
plt.scatter(heartdiseaseAgeCategory['AgeCategory'], heartdiseaseAgeCategory['Count'], color=colorPick4)
plt.text(0.1, 1.8, f'Correlation Coefficient: {.2334:.2f}', fontsize=12, color='red')
plt.xlabel("Age Categories")
plt.ylabel("Number of People")
plt.title("Number of People in Each Age Category with Heart Disease")
plt.savefig("./Resources/AgeWHeartDiseaseScatter.png")

plt.show()

# %%
#Box and Whisker plot showing distribution of individuals with and without heart disease
plt.figure(figsize=(6, 4))  
plt.boxplot([yesheartDisease['BMI'], noheartDisease['BMI']], labels=['Heart Disease', 'No Heart Disease'], whis=5.5, flierprops=dict(marker='o', markerfacecolor='red', markersize=3))
plt.xlabel('Group')
plt.ylabel('BMI')
plt.title('BMI Distribution of Individuals with and without Heart Disease')
plt.text(1, -14, f'Correlation Coefficient: {.0518:.4f}', fontsize=12, color='red')
plt.tight_layout()
plt.show()

# %%
#Mean value comparison chart for BMI
yesStats = yesheartDisease['BMI'].agg('mean')
noStats = noheartDisease['BMI'].agg('mean')
colorStats = ['purple', 'chartreuse']

plt.figure(figsize=(6, 4))
plt.bar(['Heart Disease', 'No Heart Disease'], [yesStats, noStats], color=colorStats)
plt.xlabel('Group')
plt.ylabel('BMI')
plt.title('Mean value of BMI in individuals with Heart Disease and without')
plt.ylim(25, 30)
plt.tight_layout()
plt.savefig("./Resources/MeanBMIbar.png")

plt.show()

# %%
#turn Heart Disease into a binary variable for correlation
#correlate sleep with presence of heart disease
heartdiseaseDF['HeartDisease'] = heartdiseaseDF['HeartDisease'].replace({'Yes': 1, 'No': 0})
heartdiseaseDF

correlation=heartdiseaseDF['SleepTime'].corr(heartdiseaseDF['HeartDisease'])
print(correlation)
# Out:
# 0.008326646858286435

# %%
#Correlate BMI and Heart Disease
bmiCorrelation = heartdiseaseDF['BMI'].corr(heartdiseaseDF['HeartDisease'])
bmiCorrelation
# Out:
# 0.051803190655746005

# %%
#correlation of mental health and heart disease
mentalhealthCorrelation = heartdiseaseDF['MentalHealth'].corr(heartdiseaseDF['HeartDisease'])
mentalhealthCorrelation
# Out:
# 0.028590714546906072

# %%
#turning age categories into numerical values for correlation
#correlation of Age and Heart Disease
heartdiseaseDF['AgeCategory'] = heartdiseaseDF['AgeCategory'].replace({'18-24': 0, '25-29': 1, '30-34': 2, '35-39': 3, '40-44': 4, '45-49': 5, '50-54': 6, '55-59': 7, '60-64': 8, '65-69': 9, '70-74': 10, '75-79': 11, '80 or older': 12})
heartdiseaseDF

agecorrelation = heartdiseaseDF['AgeCategory'].corr(heartdiseaseDF['HeartDisease'])
agecorrelation
# Out:
# 0.23343223812190994

# %%
#turning the "Smoking" variable into a binary variable
heartdiseaseDF['HeartDisease'] = heartdiseaseDF['HeartDisease'].replace({'Yes': 1, 'No': 0})
heartdiseaseDF
heartdiseaseDF['Smoking'] = heartdiseaseDF['Smoking'].replace({'Yes': 1, 'No': 0})
heartdiseaseDF
# Out:
#         HeartDisease    BMI  Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                  0  16.60        1              No     No             3.0
# 1                  0  20.34        0              No    Yes             0.0
# 2                  0  26.58        1              No     No            20.0
# 3                  0  24.21        0              No     No             0.0
# 4                  0  23.71        0              No     No            28.0
# ...              ...    ...      ...             ...    ...             ...
# 319790             1  27.41        1              No     No             7.0
# 319791             0  29.84        1              No     No             0.0
# 319792             0  24.24        0              No     No             0.0
# 319793             0  32.81        0              No     No             0.0
# 319794             0  46.56        0              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# 0               30.0          No  Female            7     White      Yes
# 1                0.0          No  Female           12     White       No
# 2               30.0          No    Male            9     White      Yes
# 3                0.0          No  Female           11     White       No
# 4                0.0         Yes  Female            4     White       No
# ...              ...         ...     ...          ...       ...      ...
# 319790           0.0         Yes    Male            8  Hispanic      Yes
# 319791           0.0          No    Male            3  Hispanic       No
# 319792           0.0          No  Female            5  Hispanic       No
# 319793           0.0          No  Female            1  Hispanic       No
# 319794           0.0          No  Female           12  Hispanic       No
#
#        PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0                   Yes  Very good        5.0    Yes            No        Yes
# 1                   Yes  Very good        7.0     No            No         No
# 2                   Yes       Fair        8.0    Yes            No         No
# 3                    No       Good        6.0     No            No        Yes
# 4                   Yes  Very good        8.0     No            No         No
# ...                 ...        ...        ...    ...           ...        ...
# 319790               No       Fair        6.0    Yes            No         No
# 319791              Yes  Very good        5.0    Yes            No         No
# 319792              Yes       Good        6.0     No            No         No
# 319793               No       Good       12.0     No            No         No
# 319794              Yes       Good        8.0     No            No         No
#
# [319795 rows x 18 columns]

# %%
#Correlation of Smoking and Heart Disease
smokingCorrelation = heartdiseaseDF['Smoking'].corr(heartdiseaseDF['HeartDisease'])
smokingCorrelation
# Out:
# 0.10776415602593753

# %%
#Turning alcohol drinking into a binary variable
heartdiseaseDF['AlcoholDrinking'] = heartdiseaseDF['AlcoholDrinking'].replace({'Yes': 1, 'No': 0})
heartdiseaseDF
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking Stroke  PhysicalHealth  \
# 0                  0  16.60        1                0     No             3.0
# 1                  0  20.34        0                0    Yes             0.0
# 2                  0  26.58        1                0     No            20.0
# 3                  0  24.21        0                0     No             0.0
# 4                  0  23.71        0                0     No            28.0
# ...              ...    ...      ...              ...    ...             ...
# 319790             1  27.41        1                0     No             7.0
# 319791             0  29.84        1                0     No             0.0
# 319792             0  24.24        0                0     No             0.0
# 319793             0  32.81        0                0     No             0.0
# 319794             0  46.56        0                0     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# 0               30.0          No  Female            7     White      Yes
# 1                0.0          No  Female           12     White       No
# 2               30.0          No    Male            9     White      Yes
# 3                0.0          No  Female           11     White       No
# 4                0.0         Yes  Female            4     White       No
# ...              ...         ...     ...          ...       ...      ...
# 319790           0.0         Yes    Male            8  Hispanic      Yes
# 319791           0.0          No    Male            3  Hispanic       No
# 319792           0.0          No  Female            5  Hispanic       No
# 319793           0.0          No  Female            1  Hispanic       No
# 319794           0.0          No  Female           12  Hispanic       No
#
#        PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0                   Yes  Very good        5.0    Yes            No        Yes
# 1                   Yes  Very good        7.0     No            No         No
# 2                   Yes       Fair        8.0    Yes            No         No
# 3                    No       Good        6.0     No            No        Yes
# 4                   Yes  Very good        8.0     No            No         No
# ...                 ...        ...        ...    ...           ...        ...
# 319790               No       Fair        6.0    Yes            No         No
# 319791              Yes  Very good        5.0    Yes            No         No
# 319792              Yes       Good        6.0     No            No         No
# 319793               No       Good       12.0     No            No         No
# 319794              Yes       Good        8.0     No            No         No
#
# [319795 rows x 18 columns]

# %%
#Correlation of Drinking and Heart Disease
DrinkingCorrelation = heartdiseaseDF['AlcoholDrinking'].corr(heartdiseaseDF['HeartDisease'])
DrinkingCorrelation
# Out:
# -0.03207974262500583

# %%
heartdiseaseDF['HeartDisease'] = heartdiseaseDF['HeartDisease'].replace({1: 'Yes', 0: 'No'})

# %%
heartdiseaseDF.head()
# Out:
#   HeartDisease    BMI  Smoking  AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60        1                0     No             3.0
# 1           No  20.34        0                0    Yes             0.0
# 2           No  26.58        1                0     No            20.0
# 3           No  24.21        0                0     No             0.0
# 4           No  23.71        0                0     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female            7  White      Yes
# 1           0.0          No  Female           12  White       No
# 2          30.0          No    Male            9  White      Yes
# 3           0.0          No  Female           11  White       No
# 4           0.0         Yes  Female            4  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# 1              Yes  Very good        7.0     No            No         No
# 2              Yes       Fair        8.0    Yes            No         No
# 3               No       Good        6.0     No            No        Yes
# 4              Yes  Very good        8.0     No            No         No

# %%
#turning heart disease, smoking, alcohol drinking and age category values back to their original value
heartdiseaseDF['HeartDisease'] = heartdiseaseDF['HeartDisease'].replace({1: 'Yes', 0: 'No'})
heartdiseaseDF['Smoking'] = heartdiseaseDF['Smoking'].replace({1: 'Yes', 0: 'No'})
heartdiseaseDF['AlcoholDrinking'] = heartdiseaseDF['AlcoholDrinking'].replace({1: 'Yes', 0: 'No'})
heartdiseaseDF['AgeCategory'] = heartdiseaseDF['AgeCategory'].replace({0: '18-24', 1: '25-29', 2: '30-34', 3: '35-39', 4: '40-44', 5: '45-49', 6: '50-54', 7: '55-59', 8: '60-64', 9: '65-69', 10: '70-74', 11: '75-79', 12: '80 or older'})
heartdiseaseDF
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# 0               30.0          No  Female        55-59     White      Yes
# 1                0.0          No  Female  80 or older     White       No
# 2               30.0          No    Male        65-69     White      Yes
# 3                0.0          No  Female        75-79     White       No
# 4                0.0         Yes  Female        40-44     White       No
# ...              ...         ...     ...          ...       ...      ...
# 319790           0.0         Yes    Male        60-64  Hispanic      Yes
# 319791           0.0          No    Male        35-39  Hispanic       No
# 319792           0.0          No  Female        45-49  Hispanic       No
# 319793           0.0          No  Female        25-29  Hispanic       No
# 319794           0.0          No  Female  80 or older  Hispanic       No
#
#        PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0                   Yes  Very good        5.0    Yes            No        Yes
# 1                   Yes  Very good        7.0     No            No         No
# 2                   Yes       Fair        8.0    Yes            No         No
# 3                    No       Good        6.0     No            No        Yes
# 4                   Yes  Very good        8.0     No            No         No
# ...                 ...        ...        ...    ...           ...        ...
# 319790               No       Fair        6.0    Yes            No         No
# 319791              Yes  Very good        5.0    Yes            No         No
# 319792              Yes       Good        6.0     No            No         No
# 319793               No       Good       12.0     No            No         No
# 319794              Yes       Good        8.0     No            No         No
#
# [319795 rows x 18 columns]

# %%
#Pie graphs of gender breakdowns 
genderedheartDisease = yesheartDisease.groupby('HeartDisease')['Sex'].value_counts()
genderednoheartDisease = noheartDisease.groupby('HeartDisease')['Sex'].value_counts()
allgenderData = heartdiseaseDF.groupby('Sex').size()

genderedheartDisease.plot(kind='pie', y='Sex', figsize=(5, 5), autopct='%1.1f%%', legend=False)
plt.ylabel('Sex')
plt.title('Gender Breakdown of Respondents with Heart Disease')
plt.show()

genderednoheartDisease.plot(kind='pie', y='Sex', figsize=(5, 5), autopct='%1.1f%%', legend=False)
plt.ylabel('Sex')
plt.title('Gender Breakdown of Respondents without Heart Disease')
plt.show()

allgenderData.plot(kind='pie', y='Sex', figsize=(5, 5), autopct='%1.1f%%', legend=False)
plt.ylabel('Sex')
plt.title('Gender Breakdown of Respondents')
plt.show()

# %%
genderColors = ['lightpink','lightskyblue']
allgenderData.plot(kind='pie', y='Sex', figsize=(5, 5), autopct='%1.1f%%', legend=False, colors = genderColors)
plt.title('Gender Breakdown of Respondents')
plt.savefig("./Resources/TotalSexPie.png")

plt.show()

# %%
#sleep time charts
heartdiseasesleepTime = yesheartDisease.groupby("HeartDisease")["SleepTime"].value_counts()
noheartdiseasesleepTime = noheartDisease.groupby("HeartDisease")["SleepTime"].value_counts()
allheartdisease = heartdiseaseDF.groupby("HeartDisease")["SleepTime"].value_counts()

heartdiseaseSleep = heartdiseasesleepTime.groupby("SleepTime").value_counts()
numberperCategory = heartdiseasesleepTime.sort_values(ascending=True)
numberperCategory.plot(kind="bar", color = 'blue', figsize=(8,4))
plt.xlabel("Sleep Time")
plt.ylabel("Number with Heart Disease")
plt.show()

heartdiseaseSleep = noheartdiseasesleepTime.groupby("SleepTime").value_counts()
numberperCategory = noheartdiseasesleepTime.sort_values(ascending=True)
numberperCategory.plot(kind="bar", color = 'blue', figsize=(8,4))
plt.xlabel("Sleep Time")
plt.ylabel("Number without Heart Disease")
plt.show()

heartdiseaseSleep = allheartdisease.groupby("SleepTime").value_counts()
numberperCategory = allheartdisease.sort_values(ascending=True)
numberperCategory.plot(kind="bar", color = 'blue', figsize=(8,4))
plt.xlabel("Sleep Time")
plt.ylabel("Number with Heart Disease")
plt.show()

# %%
#Boxplot charting sleep time for individuals with and without heart disease
plt.figure(figsize=(6, 4))  
plt.boxplot([yesheartDisease['SleepTime'], noheartDisease['SleepTime']], labels=['Heart Disease', 'No Heart Disease'], whis=5.5, flierprops=dict(marker='o', markerfacecolor='red', markersize=3))
plt.xlabel('Group')
plt.ylabel('Amount of Sleep (Hours)')
plt.title('Amount of Sleep for Individuals with and without Heart Disease')
plt.text(1, -8, f'Correlation Coefficient: {.0083:.4f}', fontsize=12, color='red')
plt.grid(alpha = .25)
plt.tight_layout()
plt.savefig("./Resources/SleepWhisker.png")

plt.show()

# %%
#BMI boxplot
boxplot_style = {
    'whiskerprops': {'linewidth': 2, 'color': 'palevioletred'},
    'medianprops': {'linewidth': 2, 'color': 'mintcream'},
    'flierprops': {'marker': 'o', 'markerfacecolor': 'blanchedalmond', 'markersize': 6},
    'boxprops': {'facecolor': 'lightblue'},
    'capprops': {'color': 'black', 'linewidth': 1}
}
plt.figure(figsize=(8, 6))  
plt.boxplot([yesheartDisease['BMI'], noheartDisease['BMI']], labels=['Heart Disease', 'No Heart Disease'], 
             whis=5.5, patch_artist = True, **boxplot_style)
plt.xlabel('Group')
plt.ylabel('BMI')
plt.grid(alpha = .25)
plt.title('BMI Distribution by Heart Disease')
plt.savefig("./Resources/BMIwhisker.png")

plt.show()

# %%
#Pie charts showing race breakdown
raceheartDisease = yesheartDisease.groupby('HeartDisease')['Race'].value_counts()
racenoheartDisease = noheartDisease.groupby('HeartDisease')['Race'].value_counts()
allraceData = heartdiseaseDF.groupby('Race').size()

raceheartDisease.plot(kind='pie', y='Race', figsize=(5, 5), autopct='%1.1f%%', legend=False)
plt.ylabel('Race')
plt.title('Race Breakown of Respondents with Heart Disease')
plt.show()

racenoheartDisease.plot(kind='pie', y='Race', figsize=(5, 5), autopct='%1.1f%%', legend=False)
plt.ylabel('Race')
plt.title('Race Breakdown of Respondents without Heart Disease')
plt.show()

allraceData.plot(kind='pie', y='Race', figsize=(5, 5), autopct='%1.1f%%', legend=False)
plt.ylabel('Race')
plt.title('Race Breakdown of Respondents')
plt.show()

# %%
#Individuals with heart disease breakdown on whether they smoke or drink alcohol
yesheartdiseaseSmoking = yesheartDisease.groupby('HeartDisease')['Smoking'].value_counts()
yesheartdiseaseDrinking = yesheartDisease.groupby('HeartDisease')['AlcoholDrinking'].value_counts()

lifestyle = {
    "Smoking": yesheartdiseaseSmoking,
    "Alcohol Drinking": yesheartdiseaseDrinking
}

lifestyleDF = pd.DataFrame(lifestyle)
lifestyleDF
# Out:
#                   Smoking  Alcohol Drinking
# HeartDisease
# Yes          No     11336             26232
#              Yes    16037              1141

# %%
heartdiseaseSmoking = heartdiseaseDF.groupby('HeartDisease')['Smoking'].value_counts()
heartdiseaseDrinking = heartdiseaseDF.groupby('HeartDisease')['AlcoholDrinking'].value_counts()

# %%
#bar graph showing individuals with heart disease and whether they smoke or drink alcohol
categories = ['Smoking', 'Alcohol Drinking']
yes_values = [16037, 11336]
no_values = [11336, 26232]

index = range(len(categories))
bar_width = 0.35

plt.bar(index, yes_values, bar_width, label='Yes')
plt.bar([i + bar_width for i in index], no_values, bar_width, label='No')

plt.xlabel('Lifestyle Choices')
plt.ylabel('Count of People with Heart Disease')
plt.xticks([i + bar_width/2 for i in index], categories)
plt.title('Lifestyle Choices of People with Heart Disease')
plt.legend()
plt.savefig("./Resources/HeartDiseaseLifestyleBar.png")

plt.show()

# %%
#same information as above presented as a line graph
categories = ['SmokingYes', 'SmokingNo', 'Alcohol Drinking Yes', 'Alcohol Drinking No']
smokingValues = [16037, 11336, 0, 0]
drinkingValues = [0, 0, 1141, 26232]

plt.plot(categories[:2], smokingValues[:2], marker='o', label='Smoking')
plt.plot(categories[2:], drinkingValues[2:], marker='o', label='Alcohol Drinking')

plt.xlabel('Lifestyle Choices')
plt.ylabel('Count of People with Heart Disease')
plt.legend()
plt.title('Lifestyle Choice and Presence of Heart Disease')
plt.text(1, -6500, f'Smoking Correlation Coefficient: {.1078:.4f}', fontsize=12, color='red', va='top', ha='center')
plt.text(1, -5000, f'Alcohol Drinking Correlation Coefficient: {-.0321:.4f}', fontsize=12, color='red', va='top', ha='center')
plt.savefig("./Resources/HeartDiseaseLifestyleScatter.png")

plt.show()

# %%
#Count of individuals with heart disease and their respective general health
gen_health_heart_disease = yesheartDisease["GenHealth"].value_counts()
gen_health_heart_disease
# Out:
# GenHealth
# Good         9558
# Fair         7084
# Very good    5381
# Poor         3850
# Excellent    1500
# Name: count, dtype: int64

# %%
#Bar graph showing all respondents respective general health as well as heart disease status
x = ['Poor', 'Fair', 'Good', 'Very Good', 'Excellent']
noHeart = [7439, 27593, 83571, 108477, 65342]
yesHeart = [3850, 7084, 9558, 5381, 1500]

plt.bar(x, yesHeart, color='thistle')
plt.bar(x, noHeart, bottom = yesHeart, color='palegreen')
plt.legend(['Has Heart Disease', 'No Heart Disease'])
plt.grid(alpha = .15)
plt.title('General Health: Heart Disease vs. No Heart Disease')
plt.ylabel('Number in Population')
plt.xlabel('General Health')
plt.savefig("./Resources/GenHealthBar.png")

plt.show()

# %%
labels1 = gen_health_heart_disease.index.values
pieColor = ['gainsboro', 'navajowhite','thistle', 'aquamarine','salmon']
plt.pie(gen_health_heart_disease,labels = labels1, autopct="%1.1f%%", 
        wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' },colors = pieColor)
plt.title('General Health with Heart Disease')
plt.tight_layout()
plt.savefig("./Resources/GenHealthPie.png")

plt.show()

# %%
#bar graph that shows the break down of age category and presence of heart disease
x = ['18-24', '25-29', '20-34', '35-39', '40-44','45-49','50-54',
    '55-59', '60-64', '65-69', '70-74','75-79', '80 or older']
yesHeartAge = [130, 133, 226, 296, 486, 744, 1383, 2202, 
           3327, 4101, 4847, 4049, 5449]
noHeartAge = [20934, 16822, 18527, 20254, 20520, 21047, 23999,
             27555, 30359, 30050, 26218, 17433, 18704]

plt.bar(x, yesHeartAge, color= 'gold')
plt.bar(x, noHeartAge, bottom = yesHeartAge, color='powderblue')
plt.legend(['Has Heart Disease', 'No Heart Disease'])
plt.xticks(rotation = 90)
plt.grid(alpha = .15)
plt.title('Age Category: Heart Disease vs. No Heart Disease')
plt.ylabel('Number in Population')
plt.xlabel('Age Category')
plt.savefig("./Resources/AgeCatHeartDiseaseVSNoBar.png")

plt.show()

# %%
#donut charts showing race breakdown
# Data for the first donut chart
raceCount = yesheartDisease['Race'].value_counts()
raceLabel = raceCount.index.values
pieColor1 = ['lightskyblue', 'mistyrose','wheat','tomato','lightsteelblue','springgreen']

# Data for the second donut chart
allRaceData = heartdiseaseDF['Race'].value_counts()
allRaceLabel = allRaceData.index.values

fig, axs = plt.subplots(1, 2, figsize=(10, 5))

# Plot the first donut chart
axs[0].pie(allRaceData, labels=allRaceLabel, autopct="%1.1f%%",
           wedgeprops={'linewidth': 3, 'edgecolor': 'white'},
           colors=pieColor1, textprops={'fontsize': 8})
axs[0].set_title('Dataset Composition by Race')
donut_boy2 = plt.Circle((0, 0), 0.735, color='white')
axs[0].add_artist(donut_boy2)

# Plot the second donut chart
axs[1].pie(raceCount, labels=raceLabel, autopct="%1.1f%%",
           wedgeprops={'linewidth': 3, 'edgecolor': 'white'},
           colors=pieColor1, textprops={'fontsize': 6})
axs[1].set_title('% of Dataset with Heart Disease by Race')
donut_boy1 = plt.Circle((0, 0), 0.735, color='white')
axs[1].add_artist(donut_boy1)

# Show charts
plt.tight_layout()
plt.savefig("./Resources/RaceDonuts.png")

plt.show()
